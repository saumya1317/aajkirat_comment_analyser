# %%
import kagglehub
import os

import pickle

path = kagglehub.dataset_download("lakshmi25npathi/imdb-dataset-of-50k-movie-reviews")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 25.7M/25.7M [00:00<00:00, 47.1MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/lakshmi25npathi/imdb-dataset-of-50k-movie-reviews/versions/1

# %%
import pandas as pd
import numpy as np

# %%
print(os.listdir(path))
csv_file =os.path.join(path,'IMDB Dataset.csv')
# Out:
# ['IMDB Dataset.csv']

# %%
df = pd.read_csv(csv_file)

# %%
df.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %% [markdown]
# text cleaning
# 1: sample 10000 rows
# 2; remove html tags
# 3: remove special character
# 4:convert everything to lower case
# 5:remove stop wors
# 6:stemming
# Stemming is a preprocessing technique in Natural Language Processing (NLP) that reduces words to their root or base form by removing suffixes, prefixes, or other derived forms. It helps in normalizing text data for further analysis by treating similar words with the same base meaning as identical.

# %%
df =df.sample(10000)

# %%
df.shape
# Out:
# (10000, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, 11144 to 18401
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   review     10000 non-null  object
#  1   sentiment  10000 non-null  object
# dtypes: object(2)
# memory usage: 234.4+ KB

# %%
##encoding
df['sentiment'].replace({'positive':1,'negative':0},inplace=True)
# Out:
# <ipython-input-9-cb5fffc8e2ce>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['sentiment'].replace({'positive':1,'negative':0},inplace=True)
# <ipython-input-9-cb5fffc8e2ce>:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# ...

# %%
df.head()
# Out:
#                                                   review  sentiment
# 11144  Besides the fact that this guy is a liar, he i...          0
# 40614  This 1947 film stars and was directed and writ...          1
# 22059  I've seen this film because I had do (my job i...          0
# 3945   There is not one character on this sitcom with...          0
# 34836  This movie is phoniness incarnate, a straight ...          0

# %%
import re
clean = re.compile('<.*?>')
re.sub(clean,'',df.iloc[2].review)
# Out:
# 'I\'ve seen this film because I had do (my job includes seeing movies of all kinds). I couldn\'t stop thinking "who gave money to make such an awful film and also submit it to Cannes Festival!" It wasn\'t only boring, the actors were awful as well. It was one of the worst movies I\'ve ever seen.'

# %%
def clean_html(text):
   clean = re.compile('<.*?>')
   return re.sub(clean,'',text)

# %%
df['review']=df['review'].apply(clean_html)

# %%
df.head()
# Out:
#                                                   review  sentiment
# 11144  Besides the fact that this guy is a liar, he i...          0
# 40614  This 1947 film stars and was directed and writ...          1
# 22059  I've seen this film because I had do (my job i...          0
# 3945   There is not one character on this sitcom with...          0
# 34836  This movie is phoniness incarnate, a straight ...          0

# %%
#converting everything to lowercase
def convert_lower(text):
  return text.lower()

# %%
df['review'] =df['review'].apply(convert_lower)

# %%
df.head()
# Out:
#                                                   review  sentiment
# 11144  besides the fact that this guy is a liar, he i...          0
# 40614  this 1947 film stars and was directed and writ...          1
# 22059  i've seen this film because i had do (my job i...          0
# 3945   there is not one character on this sitcom with...          0
# 34836  this movie is phoniness incarnate, a straight ...          0

# %%
def remove (text):
  x=' '
  for i in text :
    if i.isalnum():
      x =x+i
    else:
        x= x+ ' '
  return x

# %%
df['review']=df['review'].apply(remove)

# %%
df.head()
# Out:
#                                                   review  sentiment
# 11144   besides the fact that this guy is a liar  he ...          0
# 40614   this 1947 film stars and was directed and wri...          1
# 22059   i ve seen this film because i had do  my job ...          0
# 3945    there is not one character on this sitcom wit...          0
# 34836   this movie is phoniness incarnate  a straight...          0

# %%
#remove the stopwords
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from nltk.corpus import stopwords

# %%
def remove_stop(text):
  x= []
  for i in text.split():

    if i not in stopwords.words('english'):
      x.append(i)
  y=x[:]
  x.clear()
  return y

# %%
df['review']= df['review'].apply(remove_stop)

# %%
df.head()
# Out:
#                                                   review  sentiment
# 11144  [besides, fact, guy, liar, also, total, idiot,...          0
# 40614  [1947, film, stars, directed, written, orson, ...          1
# 22059  [seen, film, job, includes, seeing, movies, ki...          0
# 3945   [one, character, sitcom, redeeming, qualities,...          0
# 34836  [movie, phoniness, incarnate, straight, 11, 10...          0

# %%
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

# %%
y=[]
def stem_words(text):
  for i in text:
      y.append(ps.stem(i))
  z=y[:]
  y.clear()
  return z

# %%
df['review']=df['review'].apply(stem_words)

# %%
df.head()
# Out:
#                                                   review  sentiment
# 11144  [besid, fact, guy, liar, also, total, idiot, t...          0
# 40614  [1947, film, star, direct, written, orson, wel...          1
# 22059  [seen, film, job, includ, see, movi, kind, sto...          0
# 3945   [one, charact, sitcom, redeem, qualiti, self, ...          0
# 34836  [movi, phoni, incarn, straight, 11, 10, phoni,...          0

# %%
def join_back(list):
  return " ".join(list)

# %%
df['review']=df['review'].apply(join_back)

# %%
df.head()
# Out:
#                                                   review  sentiment
# 11144  besid fact guy liar also total idiot thief com...          0
# 40614  1947 film star direct written orson well funki...          1
# 22059  seen film job includ see movi kind stop think ...          0
# 3945   one charact sitcom redeem qualiti self center ...          0
# 34836  movi phoni incarn straight 11 10 phoni scale f...          0

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv =CountVectorizer(max_features=1000)

# %%
x = cv.fit_transform(df['review']).toarray()

# %%
y = df.iloc[:,-1].values

# %%
y.shape
# Out:
# (10000,)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.2)

# %%
from sklearn.naive_bayes import GaussianNB,MultinomialNB,BernoulliNB

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

# %%
model1 =LogisticRegression()
model1.fit(x_train,y_train)
model2= SVC(kernel='linear')
model2.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
clf1= GaussianNB()
clf2 = MultinomialNB()

# %%
clf1.fit(x_train,y_train)
y_pred =clf1.predict(x_test)
clf2.fit(x_train,y_train)
y_pred2 = clf2.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred2)
# Out:
# 0.834

# %%
import string
import requests
from googleapiclient.discovery import build
from sklearn.feature_extraction.text import CountVectorizer
from nltk.corpus import stopwords
import nltk
import pickle

# %%
video_id ="hxMNYkLN7tI"

# %%
api_key = "AIzaSyDDAEveCyFHFmzF3GDAatFkbeNoJvBWkdc"



youtube = build('youtube', 'v3', developerKey=api_key)

# %%
def get_comments(video_id):
    comments = []  # Reset the comments list
    try:
        nextPageToken = None
        while True:
            # Request to fetch comment threads for the given video
            request = youtube.commentThreads().list(
                part='snippet',
                videoId=video_id,
                textFormat='plainText',
                maxResults=100,  # Fetch up to 100 comments per request
                pageToken=nextPageToken  # Use pageToken for pagination
            )
            response = request.execute()

            # Extract the comments from the response
            for item in response['items']:
                comment = item['snippet']['topLevelComment']['snippet']['textDisplay']
                comments.append(comment)

            # Check if there are more comments (pagination)
            nextPageToken = response.get('nextPageToken')
            if not nextPageToken:
                break  # No more pages, exit the loop


        return comments

    except Exception as e:
        print(f"An error occurred: {e}")
        return []

# %%
def preprocess_text(text):
    text = text.lower()  # Convert to lowercase
    text = text.translate(str.maketrans('', '', string.punctuation))  # Remove punctuation
    stop_words = set(stopwords.words('english'))  # Set of stopwords
    words = text.split()  # Split the text into words
    words = [word for word in words if word not in stop_words]  # Remove stopwords
    return ' '.join(words)  # Join the words back into a string

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

def vectorize_comments(comments):

    processed_comments = [preprocess_text(comment) for comment in comments]


    vectorizer = TfidfVectorizer()
    X = vectorizer.fit_transform(processed_comments)
    X_dense = X.toarray()
    return X_dense, vectorizer

# %%
y_pred=model1.predict(X_dense)
y_pred2 = model2.predict(X_dense)
print(len(y), len(y_pred), len(y_pred2))
# Out:
# 10000 16586 16586

# %%
def predi(pred):
  if(pred==1):
    return "positive"
  elif(pred==0):
    return "negative"

# %%
  for comment, prediction in zip(comments, y_pred2):
    sentiment = predi(prediction)
    print(f"Comment: {comment}")
    print(f"Prediction: {sentiment}\n")
# Out:
# Streaming output truncated to the last 5000 lines.
# Prediction: positive
#
# Comment: Vote for maa ke liye
# Prediction: negative
#
# Comment: কমেন্ট পড়ে সেলিব্রিটি হয়ে গেলাম 😀😀
# Prediction: positive
#
# Comment: Very good and nice song
# Prediction: negative
#
# Comment: Re upload kyu hua yaar fir 😢original song ka reach down ho jayega fir 🙏
# Prediction: positive
#
# Comment: Tamanna ❤❤🔥
# Prediction: positive
#
# Comment: ❤❤❤❤❤❤❤❤
# Prediction: positive
#
# Comment: ❤❤❤❤
# Prediction: positive
#
# Comment: How many Pakistanis here???
# Prediction: positive
#
# Comment: #LearningpiePreschool #LearningpiePreschool
# Prediction: positive
#
# Comment: Poora song movie mai ku nahi dikhaya ....😢
# Prediction: negative
#
# Comment: This song is very beautiful ❤️❤️❤️
# Prediction: positive
#
# Comment: Every day kon kon sunta g 😅😅
# Prediction: negative
#
# Comment: Thank you bhaiya ❤
# Prediction: positive
#
# Comment: Very nice song 😊😊😊😊🎉🎉
# Prediction: negative
#
# Comment: ❤❤❤❤❤❤❤
# ...

# %%
import pickle
# !pip install streamlit

import streamlit as st

# %%
filename = 'youtube_model.sav'
pickle.dump(model2,open(filename,'wb'))

# %%
loaded_model =pickle.load(open('youtube_model.sav','rb'))

# %%
if st.button("Analyze Comments"):
    if video_id:
        # Fetch comments
        with st.spinner("Fetching comments..."):
            comments = get_comments(video_id)

        if comments:
            # Predict sentiments
            predictions = predict_sentiment(comments)

            # Display results
            st.subheader("Comments and Sentiments")
            for comment, prediction in zip(comments, predictions):
                sentiment = predi(prediction)
                st.write(f"**Comment:** {comment}")
                st.write(f"**Sentiment:** {sentiment}")
                st.write("---")
        else:
            st.warning("No comments found for this video.")
    else:
        st.error("Please enter a valid YouTube Video ID.")
